# %%
# !pip install spacy
# Out:
# Collecting spacy
#   Downloading spacy-3.4.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 52.5 MB/s eta 0:00:0000:01:00:01
# Collecting tqdm<5.0.0,>=4.38.0
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 4.1 MB/s eta 0:00:00
# Collecting pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4
#   Downloading pydantic-1.10.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 56.4 MB/s eta 0:00:00:00:01
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.8-py3-none-any.whl (17 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.10
#   Downloading spacy_legacy-3.0.11-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: setuptools in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy) (58.1.0)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.10/site-packages (from spacy) (21.3)
# Collecting typer<0.8.0,>=0.3.0
#   Downloading typer-0.7.0-py3-none-any.whl (38 kB)
# Collecting smart-open<7.0.0,>=5.2.1
#   Downloading smart_open-6.3.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 2.2 MB/s eta 0:00:00
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.9-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21 kB)
# Collecting wasabi<1.1.0,>=0.9.1
#   Downloading wasabi-0.10.1-py3-none-any.whl (26 kB)
# Requirement already satisfied: jinja2 in /home/codespace/.local/lib/python3.10/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/codespace/.local/lib/python3.10/site-packages (from spacy) (2.28.1)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.6/181.6 kB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.15.0 in /home/codespace/.local/lib/python3.10/site-packages (from spacy) (1.23.5)
# Collecting thinc<8.2.0,>=8.1.0
#   Downloading thinc-8.1.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (814 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 814.2/814.2 kB 24.7 MB/s eta 0:00:00
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (491 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.3/491.3 kB 19.4 MB/s eta 0:00:00
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.8-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.7/124.7 kB 6.5 MB/s eta 0:00:00
# Collecting pathy>=0.3.5
#   Downloading pathy-0.10.1-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 2.0 MB/s eta 0:00:00
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/codespace/.local/lib/python3.10/site-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Collecting blis<0.8.0,>=0.7.8
#   Downloading blis-0.7.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 66.9 MB/s eta 0:00:0000:0100:01
# Collecting confection<1.0.0,>=0.0.1
#   Downloading confection-0.0.3-py3-none-any.whl (32 kB)
# Collecting click<9.0.0,>=7.1.1
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.10/site-packages (from jinja2->spacy) (2.1.1)
# Installing collected packages: wasabi, cymem, tqdm, spacy-loggers, spacy-legacy, smart-open, pydantic, murmurhash, langcodes, click, catalogue, blis, typer, srsly, preshed, pathy, confection, thinc, spacy
# Successfully installed blis-0.7.9 catalogue-2.0.8 click-8.1.3 confection-0.0.3 cymem-2.0.7 langcodes-3.3.0 murmurhash-1.0.9 pathy-0.10.1 preshed-3.0.8 pydantic-1.10.4 smart-open-6.3.0 spacy-3.4.4 spacy-legacy-3.0.11 spacy-loggers-1.0.4 srsly-2.4.5 thinc-8.1.6 tqdm-4.64.1 typer-0.7.0 wasabi-0.10.1

# %%
# !python -m spacy download en_core_web_lg
# Out:
# Collecting en-core-web-lg==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.4.1/en_core_web_lg-3.4.1-py3-none-any.whl (587.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 2.5 MB/s eta 0:00:0000:0100:02
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from en-core-web-lg==3.4.1) (3.4.4)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (8.1.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (1.10.4)
# Requirement already satisfied: setuptools in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (58.1.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2.0.7)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (1.0.9)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2.28.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (3.0.11)
# Requirement already satisfied: numpy>=1.15.0 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (1.23.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2.4.5)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (0.10.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (0.7.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (3.3.0)
# Requirement already satisfied: jinja2 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (3.1.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (6.3.0)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (21.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (4.64.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (1.0.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (3.0.8)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/codespace/.local/lib/python3.10/site-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (4.4.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (1.26.13)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (0.0.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.10/site-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2.1.1)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.4.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
# !pip install ipywidgets
# Out:
# Collecting ipywidgets
#   Downloading ipywidgets-8.0.4-py3-none-any.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.8/137.8 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: traitlets>=4.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from ipywidgets) (5.6.0)
# Requirement already satisfied: ipython>=6.1.0 in /home/codespace/.local/lib/python3.10/site-packages (from ipywidgets) (8.7.0)
# Collecting jupyterlab-widgets~=3.0
#   Downloading jupyterlab_widgets-3.0.5-py3-none-any.whl (384 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.3/384.3 kB 15.1 MB/s eta 0:00:00
# Collecting widgetsnbextension~=4.0
#   Downloading widgetsnbextension-4.0.5-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 38.6 MB/s eta 0:00:00:00:01
# Requirement already satisfied: ipykernel>=4.5.1 in /home/codespace/.local/lib/python3.10/site-packages (from ipywidgets) (6.17.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/codespace/.local/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: pyzmq>=17 in /home/codespace/.local/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (24.0.1)
# Requirement already satisfied: psutil in /home/codespace/.local/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.4)
# Requirement already satisfied: packaging in /home/codespace/.local/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (21.3)
# Requirement already satisfied: nest-asyncio in /home/codespace/.local/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.6)
# Requirement already satisfied: tornado>=6.1 in /home/codespace/.local/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.2)
# Requirement already satisfied: debugpy>=1.0 in /home/codespace/.local/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.4)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/codespace/.local/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (7.4.7)
# Requirement already satisfied: pygments>=2.4.0 in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.13.0)
# Requirement already satisfied: pickleshare in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.33)
# Requirement already satisfied: decorator in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: backcall in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: stack-data in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: jedi>=0.16 in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.18.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/codespace/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: entrypoints in /home/codespace/.local/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.9.2 in /home/codespace/.local/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (5.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/codespace/.local/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/codespace/.local/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.11->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/codespace/.local/lib/python3.10/site-packages (from packaging->ipykernel>=4.5.1->ipywidgets) (3.0.9)
# Requirement already satisfied: executing>=1.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: pure-eval in /home/codespace/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /home/codespace/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: six in /home/codespace/.local/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.5.4)
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, ipywidgets
# Successfully installed ipywidgets-8.0.4 jupyterlab-widgets-3.0.5 widgetsnbextension-4.0.5

# %%
import spacy

nlp = spacy.load("en_core_web_lg")

# %%
# symptom synonym dataset - from data-loader.ipynb
sympsyn = [('https://ontology.drpawspaw.com/ADSO0000000059', 'Bloated Tummy', []),
 ('https://ontology.drpawspaw.com/ADSO0000000065', 'Unusual Collapse', []),
 ('https://ontology.drpawspaw.com/ADSO0000000048', 'Swelling Limbs', []),
 ('https://ontology.drpawspaw.com/ADSO0000000007', 'coughing', []),
 ('https://ontology.drpawspaw.com/ADSO0000000045', 'Weight Loss', []),
 ('https://ontology.drpawspaw.com/ADSO0000000027', 'Eye Discharge', []),
 ('https://ontology.drpawspaw.com/ADSO0000000008', 'Vomiting', []),
 ('https://ontology.drpawspaw.com/ADSO0000000078', 'Thickening of Skin', []),
 ('https://ontology.drpawspaw.com/ADSO0000000005', 'Fever', []),
 ('https://ontology.drpawspaw.com/ADSO0000000034', 'Muscle Twitching', []),
 ('https://ontology.drpawspaw.com/ADSO0000000057', 'Nausea', []),
 ('https://ontology.drpawspaw.com/ADSO0000000016', 'Blood Diarrhea', []),
 ('https://ontology.drpawspaw.com/ADSO0000000070', 'Kidney Disease', []),
 ('https://ontology.drpawspaw.com/ADSO0000000082', 'Fast Breathing', []),
 ('https://ontology.drpawspaw.com/ADSO0000000038',
  'Involuntary Eye Movements',
  []),
 ('https://ontology.drpawspaw.com/ADSO0000000097', 'Dark Discharge', []),
 ('https://ontology.drpawspaw.com/ADSO0000000076', 'Pigmentation of Skin', []),
 ('https://ontology.drpawspaw.com/ADSO0000000075',
  'Bumps on Skin',
  ['Papules']),
 ('https://ontology.drpawspaw.com/ADSO0000000029',
  'Scratching Ears',
  ['Crusting in the Ears']),
 ('https://ontology.drpawspaw.com/ADSO0000000040', 'Seizures', []),
 ('https://ontology.drpawspaw.com/ADSO0000000017', 'Lethargy', ['Low Energy']),
 ('https://ontology.drpawspaw.com/ADSO0000000006',
  'Inflammation of Joints',
  []),
 ('https://ontology.drpawspaw.com/ADSO0000000050', 'Whining', []),
 ('https://ontology.drpawspaw.com/ADSO0000000100',
  'Swelling of Ear Canals',
  []),
 ('https://ontology.drpawspaw.com/ADSO0000000023', 'Pain', []),
 ('https://ontology.drpawspaw.com/ADSO0000000053',
  'Severe Weight Loss',
  ['Reduce body Weight']),
 ('https://ontology.drpawspaw.com/ADSO0000000018', 'Anorexia', []),
 ('https://ontology.drpawspaw.com/ADSO0000000081',
  'Jaundiced Skin',
  ['Yellow Skin']),
 ('https://ontology.drpawspaw.com/ADSO0000000071', 'Electrolyte Problem', []),
 ('https://ontology.drpawspaw.com/ADSO0000000019', 'Brain Cancer', []),
 ('https://ontology.drpawspaw.com/ADSO0000000028', 'Sneezing', []),
 ('https://ontology.drpawspaw.com/ADSO0000000046',
  'Abnormal Movement of Limbs',
  []),
 ('https://ontology.drpawspaw.com/ADSO0000000067', 'Liver Disease', []),
 ('https://ontology.drpawspaw.com/ADSO0000000052', 'Severe Lameness', []),
 ('https://ontology.drpawspaw.com/ADSO0000000009', 'Diarrhea', []),
 ('https://ontology.drpawspaw.com/ADSO0000000041',
  'High Fever',
  ['Increase Body Heat', 'High Temperature']),
 ('https://ontology.drpawspaw.com/ADSO0000000047', 'Holding the Leg up', []),
 ('https://ontology.drpawspaw.com/ADSO0000000030',
  'Loss of Appetite',
  ['Reduce Appetite']),
 ('https://ontology.drpawspaw.com/ADSO0000000014', 'Limb Swelling', []),
 ('https://ontology.drpawspaw.com/ADSO0000000099', 'Redness', []),
 ('https://ontology.drpawspaw.com/ADSO0000000091', 'Weakness', []),
 ('https://ontology.drpawspaw.com/ADSO0000000025', 'Low Body Temperature', []),
 ('https://ontology.drpawspaw.com/ADSO0000000073', 'Head Injury', []),
 ('https://ontology.drpawspaw.com/ADSO0000000072', 'Anemia', []),
 ('https://ontology.drpawspaw.com/ADSO0000000096',
  'Discharge from the Valva',
  []),
 ('https://ontology.drpawspaw.com/ADSO0000000068', 'Low Blood Sugar', []),
 ('https://ontology.drpawspaw.com/ADSO0000000093',
  'Breathing Difficulties',
  ['Breathing Problems', 'Irregular Breathing']),
 ('https://ontology.drpawspaw.com/ADSO0000000024',
  'Discomfort',
  ['Uncomfortable']),
 ('https://ontology.drpawspaw.com/ADSO0000000020', 'Dehydration', []),
 ('https://ontology.drpawspaw.com/ADSO0000000022', 'Rapid Heart Beat', []),
 ('https://ontology.drpawspaw.com/ADSO0000000031',
  'Thickening of nose and foot pads',
  []),
 ('https://ontology.drpawspaw.com/ADSO0000000066', 'Eating Poison', []),
 ('https://ontology.drpawspaw.com/ADSO0000000098',
  'Odor',
  ['Bad Smell', 'Unpleasant Smell']),
 ('https://ontology.drpawspaw.com/ADSO0000000021', 'Red Inflamed Tissue', []),
 ('https://ontology.drpawspaw.com/ADSO0000000039', 'Paralysis', []),
 ('https://ontology.drpawspaw.com/ADSO0000000037',
  'Head Tilt',
  ['Head Shaking']),
 ('https://ontology.drpawspaw.com/ADSO0000000044', 'Itchiness', []),
 ('https://ontology.drpawspaw.com/ADSO0000000036', 'Excessive Saliva', []),
 ('https://ontology.drpawspaw.com/ADSO0000000026',
  'Nasal Discharge',
  ['Nasal Whistling', 'Nasal Wheezing']),
 ('https://ontology.drpawspaw.com/ADSO0000000056', 'Thirsty', []),
 ('https://ontology.drpawspaw.com/ADSO0000000000', 'Encephalitis', []),
 ('https://ontology.drpawspaw.com/ADSO0000000032', 'Pneumonia', []),
 ('https://ontology.drpawspaw.com/ADSO0000000043',
  'Difficulty Exercising',
  []),
 ('https://ontology.drpawspaw.com/ADSO0000000079',
  'Pale Gums',
  ['White gum', 'Gray gum', 'Yellow gum']),
 ('https://ontology.drpawspaw.com/ADSO0000000074', 'Skin Scaling', []),
 ('https://ontology.drpawspaw.com/ADSO0000000095',
  'Popping sound on bones',
  []),
 ('https://ontology.drpawspaw.com/ADSO0000000063', 'Alopecia', ['Hair Loss']),
 ('https://ontology.drpawspaw.com/ADSO0000000064', 'Increase Urination', []),
 ('https://ontology.drpawspaw.com/ADSO0000000049', 'Scrab Eyes', []),
 ('https://ontology.drpawspaw.com/ADSO0000000069', 'High Blood Sugar', []),
 ('https://ontology.drpawspaw.com/ADSO0000000055', 'Bruising', []),
 ('https://ontology.drpawspaw.com/ADSO0000000061', 'Fatigue', []),
 ('https://ontology.drpawspaw.com/ADSO0000000042', 'Running Nose', []),
 ('https://ontology.drpawspaw.com/ADSO0000000012', 'Stroke', []),
 ('https://ontology.drpawspaw.com/ADSO0000000015',
  'Abnormal Pain',
  ['Heavy Pain', 'Severe Pain']),
 ('https://ontology.drpawspaw.com/ADSO0000000062', 'Appetite Changes', []),
 ('https://ontology.drpawspaw.com/ADSO0000000060', 'Frequent Paning', []),
 ('https://ontology.drpawspaw.com/ADSO0000000051', 'Inability to Walk', []),
 ('https://ontology.drpawspaw.com/ADSO0000000033', 'Skin Sores', [])]

# %%
sympsyn[0][1]
# Out:
# 'Bloated Tummy'

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/python/3.10.4/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: tqdm in /usr/local/python/3.10.4/lib/python3.10/site-packages (from nltk) (4.64.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from nltk) (2022.10.31)
# Requirement already satisfied: click in /usr/local/python/3.10.4/lib/python3.10/site-packages (from nltk) (8.1.3)
# Requirement already satisfied: joblib in /home/codespace/.local/lib/python3.10/site-packages (from nltk) (1.2.0)

# %%
import nltk

nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/codespace/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Define more synonyms with the help of NLTK WordNet
from nltk.corpus import wordnet

def generate_synonyms(uri, keyword, syns):
    for synonym in wordnet.synsets(keyword):
        for item in synonym.lemmas():
            if keyword != synonym.name() and len(synonym.lemma_names()) > 1:
                syns.append(item.name())
    return (uri, keyword, syns)

# %%
for idx, (uri, keyword, syns) in enumerate(sympsyn):
    sympsyn[idx] = generate_synonyms(uri, keyword, syns)

# %%
sympsyn[0]
# Out:
# ('https://ontology.drpawspaw.com/ADSO0000000059', 'Bloated Tummy', [])

# %%
expanded_symp = []

def is_exist(keyword, collection):
    for idx,word,syns in collection:
        if keyword == word:
            return True

for idx,word,syns in sympsyn:
    for s in syns:
        if not is_exist(s, sympsyn):
            expanded_symp.append((uri, s))
    if not is_exist(word, sympsyn):
        expanded_symp.append((uri, word))

# %%
len(expanded_symp)
# Out:
# 216

# %%
expanded_symp[0]
# Out:
# ('https://ontology.drpawspaw.com/ADSO0000000033', 'cough')

# %%
def get_similarity(ne, idx, word):
    w1 = nlp(ne)
    w2 = nlp(word)
    return (idx, word, w1.similarity(w2))

nes = ["high body temperature"]

# for idx, (uri, word) in enumerate(expanded_symp):
#     expanded_symp[idx] = get_similarity(nes[0], uri, word)

# %%
# sorted(expanded_symp, key=lambda x:x[2], reverse=True)
# Out:
# [('https://ontology.drpawspaw.com/ADSO0000000033',
#   'Reduce body Weight',
#   0.7052485903797944),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'flatness',
#   0.607145956787246),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'dehydration',
#   0.6067992004885375),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'dehydration',
#   0.6067992004885375),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'desiccation',
#   0.6016333427813714),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'desiccation',
#   0.6016333427813714),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'evaporation',
#   0.5833822244581235),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'inflammation',
#   0.5548220513855556),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'Uncomfortable',
#   0.5439616017908863),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'botheration',
#   0.5326552050053484),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'looseness',
#   0.5283791744041092),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'irritation',
#   0.5257391278161594),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'stroking',
#   0.5241613591021396),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'regurgitation',
#   0.5117807233466084),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'uncomfortableness',
#   0.5108439131850916),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'Irregular Breathing',
#   0.5078706324065063),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'tiredness',
#   0.5071835139713656),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'itchiness',
#   0.5068100554240667),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'High Temperature',
#   0.5002744200022209),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'sickness',
#   0.49382802476022836),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'slackness',
#   0.49284876517350434),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'vomiting',
#   0.4836477841052001),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'discomfort',
#   0.4772177124112873),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'discomfort',
#   0.4772177124112873),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'weariness',
#   0.4720696920483279),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'redness',
#   0.47135468323321067),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'redness',
#   0.47135468323321067),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'itching',
#   0.46698321022367734),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'sluggishness',
#   0.465170345141211),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'sluggishness',
#   0.465170345141211),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'soreness',
#   0.46213220461238774),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'weakness',
#   0.458593415231871),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'weakness',
#   0.458593415231871),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'disgorgement',
#   0.45507156056700854),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'puking',
#   0.4520827651244572),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'infliction',
#   0.4256613774371802),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'solidus',
#   0.42468663160921555),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'bother',
#   0.41654976803100774),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'hurting',
#   0.4160261141824569),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'failing',
#   0.41379609204613355),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'paralysis',
#   0.4119917124467556),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'painfulness',
#   0.41067921568495824),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'stroke',
#   0.3979993601783844),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'stroke',
#   0.3979993601783844),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'stroke',
#   0.3979993601783844),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'stroke',
#   0.3979993601783844),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'stroke',
#   0.3979993601783844),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'stroke',
#   0.3979993601783844),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'diagonal',
#   0.3906717958931472),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'Breathing Problems',
#   0.3863833864843025),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'helplessness',
#   0.386381590065144),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'scent',
#   0.3849032579026378),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'wound',
#   0.3839533054328291),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'Increase Body Heat',
#   0.3820475241035506),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'Crusting in the Ears',
#   0.37648347350350914),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'Nasal Wheezing',
#   0.3741881731390233),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'Nasal Whistling',
#   0.35543759787606066),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'nuisance',
#   0.3540534568694925),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'Reduce Appetite',
#   0.34896143124368983),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'regurgitate',
#   0.3452023394438096),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'capture',
#   0.3450574527370509),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'capture',
#   0.3450574527370509),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'fatigue',
#   0.3423815166655762),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'fatigue',
#   0.3423815166655762),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'fatigue',
#   0.3423815166655762),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'fatigue',
#   0.3423815166655762),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'tire', 0.3291813969257467),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'tire', 0.3291813969257467),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'cough',
#   0.3209665809527297),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'pain', 0.3197494791667272),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'pain', 0.3197494791667272),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'pain', 0.3197494791667272),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'pain', 0.3197494791667272),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'pain', 0.3197494791667272),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'pain', 0.3197494791667272),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'pain', 0.3197494791667272),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'lassitude',
#   0.31700411907558235),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'lassitude',
#   0.31700411907558235),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'sneezing',
#   0.31534451767988614),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'annoyance',
#   0.3142988573941823),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'screech',
#   0.31287225777155653),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'Low Energy',
#   0.3104856595356073),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'fever',
#   0.3030373907639463),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'anaemia',
#   0.26827557603082514),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'anaemia',
#   0.26827557603082514),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'odor', 0.2677177871269165),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'odor', 0.2677177871269165),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'creak',
#   0.26111050234060296),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'anemia',
#   0.25441776078146894),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'anemia',
#   0.25441776078146894),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'aroma',
#   0.2390533325506809),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'pyrexia',
#   0.23564272917505075),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'odour',
#   0.23497419763950977),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'odour',
#   0.23497419763950977),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'languor',
#   0.23358540463204344),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'red', 0.23080802548364723),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'accident',
#   0.22640910970018213),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'lethargy',
#   0.22206846146063122),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'lethargy',
#   0.22206846146063122),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'lethargy',
#   0.22206846146063122),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'encephalitis',
#   0.2213887655261905),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'trouble',
#   0.2210594220410883),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'diarrhea',
#   0.21269114789629992),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'outwear',
#   0.20497681215717273),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'spite',
#   0.20378046801579594),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'wear',
#   0.19517963071846536),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'nausea',
#   0.1848510744967016),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'emesis',
#   0.18468353891240966),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'diarrhoea',
#   0.18129087929486218),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'Head Shaking',
#   0.17670300468770775),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'itch', 0.1742267377175035),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'retch',
#   0.1709495486303272),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'smell',
#   0.16962142929609744),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'smell',
#   0.16962142929609744),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'thirsty',
#   0.16362145001084813),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'Severe Pain',
#   0.16326117155387168),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'phlegm',
#   0.16000463458736375),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'anguish',
#   0.1596903177915478),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'Unpleasant Smell',
#   0.1553289267857673),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'injure',
#   0.15054315604434618),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'Heavy Pain',
#   0.14592731602285203),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'throw',
#   0.14172659816251693),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'offend',
#   0.1395032395404243),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'yammer',
#   0.13516891179066753),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'Yellow gum',
#   0.13504371264637788),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'seizure',
#   0.13367562489734017),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'seizure',
#   0.13367562489734017),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'seizure',
#   0.13367562489734017),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'grizzle',
#   0.12913048452249193),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'Yellow Skin',
#   0.1290684549878204),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'pall', 0.1202714339748546),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'shot',
#   0.11875459211655881),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'apoplexy',
#   0.11631067727634274),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'vomit',
#   0.09618312404690749),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'vomit',
#   0.09618312404690749),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'bruise',
#   0.09295992382992331),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'bruise',
#   0.09295992382992331),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'cast',
#   0.09064377976001964),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'sneeze',
#   0.08792017203769185),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'purge',
#   0.08649406372923535),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'slash',
#   0.08523219805386685),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'hungry',
#   0.07984309974785266),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'White gum',
#   0.0788304984389204),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'Hair Loss',
#   0.06965536871229101),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'cat', 0.06547565057861189),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'jade',
#   0.06495469727547479),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'jade',
#   0.06495469727547479),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'sick',
#   0.05930548754766832),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'squeak',
#   0.04531248857037982),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'palsy',
#   0.04127209392633933),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'ictus',
#   0.04119399167693715),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'honk',
#   0.040922621004494626),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'whine',
#   0.039965209553808764),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'whine',
#   0.039965209553808764),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'whine',
#   0.039965209553808764),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'weary',
#   0.02696820738627515),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'weary',
#   0.02696820738627515),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'disgorge',
#   0.025675142127365876),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'hurt',
#   0.014309226337197773),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'hurt',
#   0.014309226337197773),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'Gray gum',
#   0.011876563184637375),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'vomit_up', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'be_sick', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'regorge', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'spue', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'throw_up', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'febrility', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'febricity', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'feverishness', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'Papules', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'raptus', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'gaining_control', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'inanition', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'screak', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'skreak', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'pain_sensation', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'painful_sensation', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'pain_in_the_neck', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'pain_in_the_neck', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'pain_in_the_ass', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'sternutation', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'looseness_of_the_bowels',
#   0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'rubor', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'impuissance', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'genus_Anemia', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'drying_up', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'olfactory_property', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'olfactory_sensation', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'olfactory_perception',
#   0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'athirst', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'cephalitis', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'phrenitis', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'contuse', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'fatigue_duty', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'wear_upon', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'tire_out', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'wear_out', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'wear_down', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'fag_out', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'cam_stroke', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'cerebrovascular_accident',
#   0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'fortuity', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'chance_event', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'virgule', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033', 'separatrix', 0.0),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'chuck',
#   -0.004566152443391898),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'puke',
#   -0.013301483986837233),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'spew',
#   -0.01752433696112857),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'barf',
#   -0.028986247407724982),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'Bad Smell',
#   -0.037644697463838535),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'fag',
#   -0.04582710614858077),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'snivel',
#   -0.048280931249804725),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'CVA',
#   -0.055549211788827234),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'upchuck',
#   -0.06494362228821668),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'ail',
#   -0.08794208690457969),
#  ('https://ontology.drpawspaw.com/ADSO0000000033',
#   'yawp',
#   -0.1585620400683418)]

# %%
# !pip install openai
# Out:
# Collecting openai
#   Downloading openai-0.25.0.tar.gz (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 2.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pandas>=1.2.3 in /home/codespace/.local/lib/python3.10/site-packages (from openai) (1.5.2)
# Collecting openpyxl>=3.0.7
#   Downloading openpyxl-3.0.10-py2.py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.1/242.1 kB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/python/3.10.4/lib/python3.10/site-packages (from openai) (4.64.1)
# Requirement already satisfied: typing-extensions in /home/codespace/.local/lib/python3.10/site-packages (from openai) (4.4.0)
# Collecting pandas-stubs>=1.1.0.11
#   Downloading pandas_stubs-1.5.2.230105-py3-none-any.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.2/148.2 kB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.10/site-packages (from openai) (1.23.5)
# Requirement already satisfied: requests>=2.20 in /home/codespace/.local/lib/python3.10/site-packages (from openai) (2.28.1)
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas>=1.2.3->openai) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas>=1.2.3->openai) (2022.6)
# Collecting types-pytz>=2022.1.1
#   Downloading types_pytz-2022.7.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.20->openai) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.20->openai) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.20->openai) (2022.9.24)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas>=1.2.3->openai) (1.16.0)
# Building wheels for collected packages: openai
#   Building wheel for openai (pyproject.toml) ... done
#   Created wheel for openai: filename=openai-0.25.0-py3-none-any.whl size=55859 sha256=92706d6e1efdda0d7a05877f9e54e5e73d54822cf2a1784e9c6e59cfd6ab363c
#   Stored in directory: /home/codespace/.cache/pip/wheels/b4/2b/95/737049113f1905133261431692b68dda34fadb3022700a4187
# Successfully built openai
# Installing collected packages: types-pytz, pandas-stubs, et-xmlfile, openpyxl, openai
# Successfully installed et-xmlfile-1.1.0 openai-0.25.0 openpyxl-3.0.10 pandas-stubs-1.5.2.230105 types-pytz-2022.7.0.0

# %%
import pandas as pd
import openai, numpy as np
from openai.embeddings_utils import get_embedding, cosine_similarity

# %%
api_key = "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"
openai.api_key = api_key

# %%
response = openai.Embedding.create(
    input=["dog", "vehicle"],
    engine="text-similarity-davinci-001"
)

emb_1 = response["data"][0]["embedding"]
emb_2 = response["data"][1]["embedding"]

np.dot(emb_1, emb_2)
# Out:
# 0.8092513169367387

# %%
for idx, (uri, word) in enumerate(expanded_symp):
    response = openai.Embedding.create(
        input=[nes[0], word],
        engine="text-similarity-davinci-001"
    )
    emb_1 = response["data"][0]["embedding"]
    emb_2 = response["data"][1]["embedding"]
    expanded_symp[idx] = (uri, word, np.dot(emb_1, emb_2))
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[59], line 2
#       1 for idx, (uri, word) in enumerate(expanded_symp):
# ----> 2     response = openai.Embedding.create(
#       3         input=[nes[0], word],
#       4         engine="text-similarity-davinci-001"
#       5     )
#       6     emb_1 = response["data"][0]["embedding"]
#       7     emb_2 = response["data"][1]["embedding"]
#
# File /usr/local/python/3.10.4/lib/python3.10/site-packages/openai/api_resources/embedding.py:34, in Embedding.create(cls, *args, **kwargs)
#      32 while True:
#      33     try:
# ---> 34         response = super().create(*args, **kwargs)
#      36         # If a user specifies base64, we'll just return the encoded string.
#      37         # This is only for the default case.
#      38         if not user_provided_encoding_format:
#
# File /usr/local/python/3.10.4/lib/python3.10/site-packages/openai/api_resources/abstract/engine_api_resource.py:115, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     107 requestor = api_requestor.APIRequestor(
#     108     api_key,
#     109     api_base=api_base,
#    (...)
#     112     organization=organization,
#     113 )
#     114 url = cls.class_url(engine, api_type, api_version)
# --> 115 response, _, api_key = requestor.request(
#     116     "post",
#     117     url,
#     118     params=params,
#     119     headers=headers,
#     120     stream=stream,
#     121     request_id=request_id,
#     122     request_timeout=request_timeout,
#     123 )
#     125 if stream:
#     126     # must be an iterator
#     127     assert not isinstance(response, OpenAIResponse)
#
# File /usr/local/python/3.10.4/lib/python3.10/site-packages/openai/api_requestor.py:181, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     160 def request(
#     161     self,
#     162     method,
#    (...)
#     169     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     170 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
#     171     result = self.request_raw(
#     172         method.lower(),
#     173         url,
#    (...)
#     179         request_timeout=request_timeout,
#     180     )
# --> 181     resp, got_stream = self._interpret_response(result, stream)
#     182     return resp, got_stream, self.api_key
#
# File /usr/local/python/3.10.4/lib/python3.10/site-packages/openai/api_requestor.py:396, in APIRequestor._interpret_response(self, result, stream)
#     388     return (
#     389         self._interpret_response_line(
#     390             line, result.status_code, result.headers, stream=True
#     391         )
#     392         for line in parse_stream(result.iter_lines())
#     393     ), True
#     394 else:
#     395     return (
# --> 396         self._interpret_response_line(
#     397             result.content, result.status_code, result.headers, stream=False
#     398         ),
#     399         False,
#     400     )
#
# File /usr/local/python/3.10.4/lib/python3.10/site-packages/openai/api_requestor.py:429, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     427 stream_error = stream and "error" in resp.data
#     428 if stream_error or not 200 <= rcode < 300:
# --> 429     raise self.handle_error_response(
#     430         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     431     )
#     432 return resp
#
# RateLimitError: Rate limit reached for default-global-with-image-limits in organization org-uZp9GE8ZVIblG89bSQf9NEtS on requests per min. Limit: 60.000000 / min. Current: 70.000000 / min. Contact support@openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://beta.openai.com/account/billing to add a payment method.

# %%
sorted(expanded_symp, key=lambda x:x[2], reverse=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 sorted(expanded_symp, key=lambda x:x[2], reverse=True)
#
# Cell In[60], line 1, in <lambda>(x)
# ----> 1 sorted(expanded_symp, key=lambda x:x[2], reverse=True)
#
# IndexError: tuple index out of range

# %%
# !pip install -U sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 52.6 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: tqdm in /usr/local/python/3.10.4/lib/python3.10/site-packages (from sentence-transformers) (4.64.1)
# Requirement already satisfied: torch>=1.6.0 in /home/codespace/.local/lib/python3.10/site-packages (from sentence-transformers) (1.13.0)
# Collecting torchvision
#   Downloading torchvision-0.14.1-cp310-cp310-manylinux1_x86_64.whl (24.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 42.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.10/site-packages (from sentence-transformers) (1.23.5)
# Requirement already satisfied: scikit-learn in /home/codespace/.local/lib/python3.10/site-packages (from sentence-transformers) (1.1.3)
# Requirement already satisfied: scipy in /home/codespace/.local/lib/python3.10/site-packages (from sentence-transformers) (1.9.3)
# Requirement already satisfied: nltk in /usr/local/python/3.10.4/lib/python3.10/site-packages (from sentence-transformers) (3.8.1)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 30.9 MB/s eta 0:00:00:00:01
# Collecting huggingface-hub>=0.4.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.4/182.4 kB 9.5 MB/s eta 0:00:00
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (682 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 682.2/682.2 kB 23.0 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/codespace/.local/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.4.0)
# Collecting filelock
#   Downloading filelock-3.9.0-py3-none-any.whl (9.7 kB)
# Requirement already satisfied: packaging>=20.9 in /home/codespace/.local/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (21.3)
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.28.1)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers) (8.5.0.96)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers) (11.7.99)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers) (11.7.99)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers) (11.10.3.66)
# Requirement already satisfied: setuptools in /usr/local/python/3.10.4/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.6.0->sentence-transformers) (58.1.0)
# Requirement already satisfied: wheel in /home/codespace/.local/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.6.0->sentence-transformers) (0.38.4)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 69.8 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.10.31)
# Requirement already satisfied: joblib in /home/codespace/.local/lib/python3.10/site-packages (from nltk->sentence-transformers) (1.2.0)
# Requirement already satisfied: click in /usr/local/python/3.10.4/lib/python3.10/site-packages (from nltk->sentence-transformers) (8.1.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/codespace/.local/lib/python3.10/site-packages (from torchvision->sentence-transformers) (9.3.0)
# Collecting torch>=1.6.0
#   Downloading torch-1.13.1-cp310-cp310-manylinux1_x86_64.whl (887.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 MB 1.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/codespace/.local/lib/python3.10/site-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/codespace/.local/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.26.13)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=cf0d363f6fc1a4f8d3d735101c93d138a4f75469bdf8c98b05d5ef6924f59b53
#   Stored in directory: /home/codespace/.cache/pip/wheels/0a/f5/dd/9d00836c4e9e279c2a59d5b0ab72dafa66cbc626a327c550dd
# Successfully built sentence-transformers
# Installing collected packages: tokenizers, sentencepiece, pyyaml, filelock, huggingface-hub, transformers, torch, torchvision, sentence-transformers
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.0
#     Uninstalling torch-1.13.0:
#       Successfully uninstalled torch-1.13.0
# Successfully installed filelock-3.9.0 huggingface-hub-0.11.1 pyyaml-6.0 sentence-transformers-2.2.2 sentencepiece-0.1.97 tokenizers-0.13.2 torch-1.13.1 torchvision-0.14.1 transformers-4.25.1

# %%
# !pip install torch --upgrade
# Out:
# Requirement already satisfied: torch in /usr/local/python/3.10.4/lib/python3.10/site-packages (1.13.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/codespace/.local/lib/python3.10/site-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/codespace/.local/lib/python3.10/site-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/codespace/.local/lib/python3.10/site-packages (from torch) (11.10.3.66)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/codespace/.local/lib/python3.10/site-packages (from torch) (8.5.0.96)
# Requirement already satisfied: typing-extensions in /home/codespace/.local/lib/python3.10/site-packages (from torch) (4.4.0)
# Requirement already satisfied: wheel in /home/codespace/.local/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.38.4)
# Requirement already satisfied: setuptools in /usr/local/python/3.10.4/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (58.1.0)

# %%
import torch.utils.checkpoint
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 import torch.utils.checkpoint
#
# ModuleNotFoundError: No module named 'torch.utils.checkpoint'

# %%
# !python -V
# Out:
# Python 3.10.4

# %%
from sentence_transformers import SentenceTransformer, util

model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /usr/local/python/3.10.4/lib/python3.10/site-packages/transformers/utils/import_utils.py:1093, in _LazyModule._get_module(self, module_name)
#    1092 try:
# -> 1093     return importlib.import_module("." + module_name, self.__name__)
#    1094 except Exception as e:
#
# File /usr/local/python/3.10.4/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File /usr/local/python/3.10.4/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:26
#      25 import torch
# ---> 26 import torch.utils.checkpoint
#      27 from torch import nn
#
# ModuleNotFoundError: No module named 'torch.utils.checkpoint'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[71], line 3
#       1 from sentence_transformers import SentenceTransformer, util
# ----> 3 model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
#
# File /usr/local/python/3.10.4/lib/python3.10/site-packages/sentence_transformers/SentenceTransformer.py:95, in SentenceTransformer.__init__(self, model_name_or_path, modules, device, cache_folder, use_auth_token)
#      87         snapshot_download(model_name_or_path,
#      88                             cache_dir=cache_folder,
#      89                             library_name='sentence-transformers',
#      90                             library_version=__version__,
#      91                             ignore_files=['flax_model.msgpack', 'rust_model.ot', 'tf_model.h5'],
#      92                             use_auth_token=use_auth_token)
#      94 if os.path.exists(os.path.join(model_path, 'modules.json')):    #Load as SentenceTransformer model
# ---> 95     modules = self._load_sbert_model(model_path)
#      96 else:   #Load with AutoModel
#      97     modules = self._load_auto_model(model_path)
#
# File /usr/local/python/3.10.4/lib/python3.10/site-packages/sentence_transformers/SentenceTransformer.py:840, in SentenceTransformer._load_sbert_model(self, model_path)
#     838 for module_config in modules_config:
#     839     module_class = import_from_string(module_config['type'])
# --> 840     module = module_class.load(os.path.join(model_path, module_config['path']))
#     841     modules[module_config['name']] = module
#     843 return modules
#
# File /usr/local/python/3.10.4/lib/python3.10/site-packages/sentence_transformers/models/Transformer.py:137, in Transformer.load(input_path)
#     135 with open(sbert_config_path) as fIn:
#     136     config = json.load(fIn)
# --> 137 return Transformer(model_name_or_path=input_path, **config)
#
# File /usr/local/python/3.10.4/lib/python3.10/site-packages/sentence_transformers/models/Transformer.py:29, in Transformer.__init__(self, model_name_or_path, max_seq_length, model_args, cache_dir, tokenizer_args, do_lower_case, tokenizer_name_or_path)
#      26 self.do_lower_case = do_lower_case
#      28 config = AutoConfig.from_pretrained(model_name_or_path, **model_args, cache_dir=cache_dir)
# ---> 29 self._load_model(model_name_or_path, config, cache_dir)
#      31 self.tokenizer = AutoTokenizer.from_pretrained(tokenizer_name_or_path if tokenizer_name_or_path is not None else model_name_or_path, cache_dir=cache_dir, **tokenizer_args)
#      33 #No max_seq_length set. Try to infer from model
#
# File /usr/local/python/3.10.4/lib/python3.10/site-packages/sentence_transformers/models/Transformer.py:49, in Transformer._load_model(self, model_name_or_path, config, cache_dir)
#      47     self._load_t5_model(model_name_or_path, config, cache_dir)
#      48 else:
# ---> 49     self.auto_model = AutoModel.from_pretrained(model_name_or_path, config=config, cache_dir=cache_dir)
#
# File /usr/local/python/3.10.4/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:462, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     458     return model_class.from_pretrained(
#     459         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     460     )
#     461 elif type(config) in cls._model_mapping.keys():
# --> 462     model_class = _get_model_class(config, cls._model_mapping)
#     463     return model_class.from_pretrained(
#     464         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     465     )
#     466 raise ValueError(
#     467     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     468     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     469 )
#
# File /usr/local/python/3.10.4/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:359, in _get_model_class(config, model_mapping)
#     358 def _get_model_class(config, model_mapping):
# --> 359     supported_models = model_mapping[type(config)]
#     360     if not isinstance(supported_models, (list, tuple)):
#     361         return supported_models
#
# File /usr/local/python/3.10.4/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:590, in _LazyAutoMapping.__getitem__(self, key)
#     588 if model_type in self._model_mapping:
#     589     model_name = self._model_mapping[model_type]
# --> 590     return self._load_attr_from_module(model_type, model_name)
#     592 # Maybe there was several model types associated with this config.
#     593 model_types = [k for k, v in self._config_mapping.items() if v == key.__name__]
#
# File /usr/local/python/3.10.4/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:604, in _LazyAutoMapping._load_attr_from_module(self, model_type, attr)
#     602 if module_name not in self._modules:
#     603     self._modules[module_name] = importlib.import_module(f".{module_name}", "transformers.models")
# --> 604 return getattribute_from_module(self._modules[module_name], attr)
#
# File /usr/local/python/3.10.4/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:553, in getattribute_from_module(module, attr)
#     551 if isinstance(attr, tuple):
#     552     return tuple(getattribute_from_module(module, a) for a in attr)
# --> 553 if hasattr(module, attr):
#     554     return getattr(module, attr)
#     555 # Some of the mappings have entries model_type -> object of another model type. In that case we try to grab the
#     556 # object at the top level.
#
# File /usr/local/python/3.10.4/lib/python3.10/site-packages/transformers/utils/import_utils.py:1083, in _LazyModule.__getattr__(self, name)
#    1081     value = self._get_module(name)
#    1082 elif name in self._class_to_module.keys():
# -> 1083     module = self._get_module(self._class_to_module[name])
#    1084     value = getattr(module, name)
#    1085 else:
#
# File /usr/local/python/3.10.4/lib/python3.10/site-packages/transformers/utils/import_utils.py:1095, in _LazyModule._get_module(self, module_name)
#    1093     return importlib.import_module("." + module_name, self.__name__)
#    1094 except Exception as e:
# -> 1095     raise RuntimeError(
#    1096         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1097         f" traceback):\n{e}"
#    1098     ) from e
#
# RuntimeError: Failed to import transformers.models.bert.modeling_bert because of the following error (look up to see its traceback):
# No module named 'torch.utils.checkpoint'

# %%
sentences = ["I'm happy", "I'm full of happiness"]

#Compute embedding for both lists
embedding_1= model.encode(sentences[0], convert_to_tensor=True)
embedding_2 = model.encode(sentences[1], convert_to_tensor=True)

# Calculate cosine similarity
util.pytorch_cos_sim(embedding_1, embedding_2)
